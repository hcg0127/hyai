# %% [markdown]
# <a href="https://colab.research.google.com/github/hcg0127/hyai/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.random.rand(100, 1)

# %%
y = 1 + (2 * x) + (.1 * np.random.rand(100, 1))

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(x, y, label = 'train', alpha=0.5)

# %%
# Linear regeression

# %%
w = np.random.randn(1)
b = np.random.randn(1)

# %%
fig = plt.figure(figsize=(6,6))

plt.scatter(x, y)
plt.plot(x, b + w * x, color = 'red')
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.yscale('log')
plt.scatter([i for i in range(n_epochs)], error_loss, s=5, c='r', label='loss')

# %%
from sklearn.linear_model import LinearRegression

linr = LinearRegression()
linr.fit(x, y)
print(linr.coef_[0], linr.intercept_)
# Out:
# [1.99694983] [1.05318324]

# %%
def mse(w, b, data):
  yhat = w * x + b
  error = y - yhat
  loss = (error ** 2).mean()
  return error, loss

# %%
def sgd(lr, x, x_grad):
  result = x - lr * x_grad
  return result

# %%
def grad(error, data):
  w_grad = -2 * (x * error).mean()
  b_grad = -2 * error.mean()
  return w_grad, b_grad

# %%
lr = 0.1
n_epochs = 1000
error_loss = [ ]
for epoch in range(n_epochs):
  error, loss = mse(w, b, x)
  error_loss.append(loss)
  w_grad, b_grad = grad(error, x)
  w = sgd(lr, w, w_grad)
  b = sgd(lr, b, b_grad)
print(w, b)
# Out:
# [1.99694983] [1.05318324]
